# %%
# Restart the session afther this cell to avoid Google Colab errors
# %pip install --upgrade --force-reinstall numpy==1.26.4 pandas
# Out:
# Collecting numpy==1.26.4
#   Downloading numpy-1.26.4.tar.gz (15.8 MB)
#      ---------------------------------------- 0.0/15.8 MB ? eta -:--:--
#      ---------------------------------------- 0.0/15.8 MB ? eta -:--:--
#      ----- ---------------------------------- 2.1/15.8 MB 9.6 MB/s eta 0:00:02
#      ----------- ---------------------------- 4.5/15.8 MB 10.9 MB/s eta 0:00:02
#      ----------------- ---------------------- 7.1/15.8 MB 11.2 MB/s eta 0:00:01
#      ----------------------- ---------------- 9.4/15.8 MB 11.3 MB/s eta 0:00:01
#      ----------------------------- --------- 12.1/15.8 MB 11.5 MB/s eta 0:00:01
#      ----------------------------------- --- 14.4/15.8 MB 11.5 MB/s eta 0:00:01
#      ---------------------------------------- 15.8/15.8 MB 11.4 MB/s  0:00:01
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Installing backend dependencies: started
#   Installing backend dependencies: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): still running...
#   Preparing metadata (pyproject.toml): still running...
#   Preparing metadata (pyproject.toml): still running...
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Collecting pandas
#   Downloading pandas-2.3.3-cp314-cp314-win_amd64.whl.metadata (19 kB)
# Collecting python-dateutil>=2.8.2 (from pandas)
#   Using cached python_dateutil-2.9.0.post0-py2.py3-none-any.whl.metadata (8.4 kB)
# Collecting pytz>=2020.1 (from pandas)
#   Downloading pytz-2025.2-py2.py3-none-any.whl.metadata (22 kB)
# Collecting tzdata>=2022.7 (from pandas)
#   Using cached tzdata-2025.2-py2.py3-none-any.whl.metadata (1.4 kB)
# Collecting six>=1.5 (from python-dateutil>=2.8.2->pandas)
#   Using cached six-1.17.0-py2.py3-none-any.whl.metadata (1.7 kB)
# Downloading pandas-2.3.3-cp314-cp314-win_amd64.whl (11.1 MB)
#    ---------------------------------------- 0.0/11.1 MB ? eta -:--:--
#    ------- -------------------------------- 2.1/11.1 MB 11.9 MB/s eta 0:00:01
#    ---------------- ----------------------- 4.7/11.1 MB 11.8 MB/s eta 0:00:01
#    ------------------------- -------------- 7.1/11.1 MB 11.9 MB/s eta 0:00:01
#    ------------------------------- -------- 8.7/11.1 MB 10.5 MB/s eta 0:00:01
#    ---------------------------------------- 11.1/11.1 MB 10.8 MB/s  0:00:01
# Using cached python_dateutil-2.9.0.post0-py2.py3-none-any.whl (229 kB)
# Downloading pytz-2025.2-py2.py3-none-any.whl (509 kB)
# Using cached six-1.17.0-py2.py3-none-any.whl (11 kB)
# Using cached tzdata-2025.2-py2.py3-none-any.whl (347 kB)
# Building wheels for collected packages: numpy
#   Building wheel for numpy (pyproject.toml): started
#   Building wheel for numpy (pyproject.toml): finished with status 'done'
#   Created wheel for numpy: filename=numpy-1.26.4-cp314-cp314-win_amd64.whl size=9919853 sha256=c795c02545574194326c174e6d5b0ab91e8b7c00cf396d5fe04e36abef467e91
#   Stored in directory: c:\users\pac61\appdata\local\pip\cache\wheels\9f\41\2d\41d9edbbdf1331835527392f3da54c7de611dc6ba3ef296215
# Successfully built numpy
# Installing collected packages: pytz, tzdata, six, numpy, python-dateutil, pandas
#
#    ---------------------------------------- 0/6 [pytz]
#    ---------------------------------------- 0/6 [pytz]
#    ---------------------------------------- 0/6 [pytz]
#    ------ --------------------------------- 1/6 [tzdata]
#    ------ --------------------------------- 1/6 [tzdata]
#    ------ --------------------------------- 1/6 [tzdata]
#   Attempting uninstall: six
#    ------ --------------------------------- 1/6 [tzdata]
#     Found existing installation: six 1.17.0
#    ------ --------------------------------- 1/6 [tzdata]
#     Uninstalling six-1.17.0:
#    ------ --------------------------------- 1/6 [tzdata]
#    ------------- -------------------------- 2/6 [six]
#       Successfully uninstalled six-1.17.0
#    ------------- -------------------------- 2/6 [six]
#    -------------------- ------------------- 3/6 [numpy]
#    -------------------- ------------------- 3/6 [numpy]
#    -------------------- ------------------- 3/6 [numpy]
#    -------------------- ------------------- 3/6 [numpy]
#    -------------------- ------------------- 3/6 [numpy]
#    -------------------- ------------------- 3/6 [numpy]
#    -------------------- ------------------- 3/6 [numpy]
#    -------------------- ------------------- 3/6 [numpy]
#    -------------------- ------------------- 3/6 [numpy]
#    -------------------- ------------------- 3/6 [numpy]
#    -------------------- ------------------- 3/6 [numpy]
#    -------------------- ------------------- 3/6 [numpy]
#    -------------------- ------------------- 3/6 [numpy]
#    -------------------- ------------------- 3/6 [numpy]
#    -------------------- ------------------- 3/6 [numpy]
#    -------------------- ------------------- 3/6 [numpy]
#    -------------------- ------------------- 3/6 [numpy]
#    -------------------- ------------------- 3/6 [numpy]
#    -------------------- ------------------- 3/6 [numpy]
#    -------------------- ------------------- 3/6 [numpy]
#    -------------------- ------------------- 3/6 [numpy]
#    -------------------- ------------------- 3/6 [numpy]
#   Attempting uninstall: python-dateutil
#    -------------------- ------------------- 3/6 [numpy]
#     Found existing installation: python-dateutil 2.9.0.post0
#    -------------------- ------------------- 3/6 [numpy]
#     Uninstalling python-dateutil-2.9.0.post0:
#    -------------------- ------------------- 3/6 [numpy]
#       Successfully uninstalled python-dateutil-2.9.0.post0
#    -------------------- ------------------- 3/6 [numpy]
#    -------------------------- ------------- 4/6 [python-dateutil]
#    --------------------------------- ------ 5/6 [pandas]
#    --------------------------------- ------ 5/6 [pandas]
#    --------------------------------- ------ 5/6 [pandas]
#    --------------------------------- ------ 5/6 [pandas]
#    --------------------------------- ------ 5/6 [pandas]
#    --------------------------------- ------ 5/6 [pandas]
#    --------------------------------- ------ 5/6 [pandas]
#    --------------------------------- ------ 5/6 [pandas]
#    --------------------------------- ------ 5/6 [pandas]
#    --------------------------------- ------ 5/6 [pandas]
#    --------------------------------- ------ 5/6 [pandas]
#    --------------------------------- ------ 5/6 [pandas]
#    --------------------------------- ------ 5/6 [pandas]
#    --------------------------------- ------ 5/6 [pandas]
#    --------------------------------- ------ 5/6 [pandas]
#    --------------------------------- ------ 5/6 [pandas]
#    --------------------------------- ------ 5/6 [pandas]
#    --------------------------------- ------ 5/6 [pandas]
#    --------------------------------- ------ 5/6 [pandas]
#    --------------------------------- ------ 5/6 [pandas]
#    --------------------------------- ------ 5/6 [pandas]
#    --------------------------------- ------ 5/6 [pandas]
#    --------------------------------- ------ 5/6 [pandas]
#    --------------------------------- ------ 5/6 [pandas]
#    --------------------------------- ------ 5/6 [pandas]
#    --------------------------------- ------ 5/6 [pandas]
#    --------------------------------- ------ 5/6 [pandas]
#    --------------------------------- ------ 5/6 [pandas]
#    --------------------------------- ------ 5/6 [pandas]
#    --------------------------------- ------ 5/6 [pandas]
#    --------------------------------- ------ 5/6 [pandas]
#    --------------------------------- ------ 5/6 [pandas]
#    --------------------------------- ------ 5/6 [pandas]
#    --------------------------------- ------ 5/6 [pandas]
#    --------------------------------- ------ 5/6 [pandas]
#    --------------------------------- ------ 5/6 [pandas]
#    --------------------------------- ------ 5/6 [pandas]
#    --------------------------------- ------ 5/6 [pandas]
#    --------------------------------- ------ 5/6 [pandas]
#    --------------------------------- ------ 5/6 [pandas]
#    --------------------------------- ------ 5/6 [pandas]
#    --------------------------------- ------ 5/6 [pandas]
#    --------------------------------- ------ 5/6 [pandas]
#    --------------------------------- ------ 5/6 [pandas]
#    --------------------------------- ------ 5/6 [pandas]
#    --------------------------------- ------ 5/6 [pandas]
#    --------------------------------- ------ 5/6 [pandas]
#    --------------------------------- ------ 5/6 [pandas]
#    --------------------------------- ------ 5/6 [pandas]
#    --------------------------------- ------ 5/6 [pandas]
#    --------------------------------- ------ 5/6 [pandas]
#    --------------------------------- ------ 5/6 [pandas]
#    --------------------------------- ------ 5/6 [pandas]
#    --------------------------------- ------ 5/6 [pandas]
#    --------------------------------- ------ 5/6 [pandas]
#    --------------------------------- ------ 5/6 [pandas]
#    --------------------------------- ------ 5/6 [pandas]
#    --------------------------------- ------ 5/6 [pandas]
#    --------------------------------- ------ 5/6 [pandas]
#    --------------------------------- ------ 5/6 [pandas]
#    --------------------------------- ------ 5/6 [pandas]
#    --------------------------------- ------ 5/6 [pandas]
#    --------------------------------- ------ 5/6 [pandas]
#    ---------------------------------------- 6/6 [pandas]
#
# Successfully installed numpy-1.26.4 pandas-2.3.3 python-dateutil-2.9.0.post0 pytz-2025.2 six-1.17.0 tzdata-2025.2
